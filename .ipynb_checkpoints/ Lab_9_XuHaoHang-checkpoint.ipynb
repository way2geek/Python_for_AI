# %%
import pandas as pd
import numpy as np

# %%
#Q1
df_left = pd.DataFrame({'key':['a','b','c'], 'lval1':np.random.normal(0, 1, 3), 'lval2':np.random.normal(0, 1, 3)})
df_right = pd.DataFrame({'key':['b','c','d'], 'rval1':np.random.normal(0, 1, 3), 'rval2':np.random.normal(0, 1, 3)})

# %%
#Q2
merge = pd.merge(df_left,df_right,how = 'left')
merge
# Out:
#   key     lval1     lval2     rval1     rval2
# 0   a  0.783535 -1.243452       NaN       NaN
# 1   b  0.540290  0.805236  0.741459  0.603282
# 2   c  0.012307 -0.583511  0.142869 -0.515241

# %%
#Q3
df_left_new = df_left.rename(columns = {'key':'key_left'})
merge = pd.merge(df_left_new,df_right,how = 'left')
merge
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-68-fff577bf88e4> in <module>
#       1 #Q3
#       2 df_left_new = df_left.rename(columns = {'key':'key_left'})
# ----> 3 merge = pd.merge(df_left_new,df_right,how = 'left')
#       4 merge
#
# ~/anaconda/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      72     validate=None,
#      73 ) -> "DataFrame":
# ---> 74     op = _MergeOperation(
#      75         left,
#      76         right,
#
# ~/anaconda/anaconda3/lib/python3.8/site-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     648             warnings.warn(msg, UserWarning)
#     649
# ...

# %%
#Q4
merge = pd.merge(df_left,df_right,how = 'right')
merge
# Out:
#   key     lval1     lval2     rval1     rval2
# 0   b  0.540290  0.805236  0.741459  0.603282
# 1   c  0.012307 -0.583511  0.142869 -0.515241
# 2   d       NaN       NaN -1.515312  0.276246

# %%
#Q5
merge = pd.merge(df_left,df_right,how = 'outer')
merge
# Out:
#   key     lval1     lval2     rval1     rval2
# 0   a  0.783535 -1.243452       NaN       NaN
# 1   b  0.540290  0.805236  0.741459  0.603282
# 2   c  0.012307 -0.583511  0.142869 -0.515241
# 3   d       NaN       NaN -1.515312  0.276246

# %%
#Q6
merge = pd.merge(df_left,df_right,how = 'inner')
merge
# Out:
#   key     lval1     lval2     rval1     rval2
# 0   b  0.540290  0.805236  0.741459  0.603282
# 1   c  0.012307 -0.583511  0.142869 -0.515241

# %%
#7
df_lsqrt = np.abs(df_left[['lval1','lval2']]).apply(np.sqrt)
df_lsqrt
# Out:
#       lval1     lval2
# 0  0.885175  1.115102
# 1  0.735044  0.897349
# 2  0.110937  0.763879

# %%
#8
df_lval = df_left[['lval1','lval2']]

sqrt_np = np.sqrt(np.abs(df_lval))
sqrt_np
# Out:
#       lval1     lval2
# 0  0.885175  1.115102
# 1  0.735044  0.897349
# 2  0.110937  0.763879

# %%
#9
df_sqrt = df_left[['lval1','lval2']].applymap(lambda x: math.sqrt(abs(x)))
df_sqrt
# Out:
#       lval1     lval2
# 0  0.885175  1.115102
# 1  0.735044  0.897349
# 2  0.110937  0.763879

# %%
#10
import requests
url_wiki = 'https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_area'
r = requests.get(url_wiki,headers ={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'})
data = pd.read_html(r.text)
df_wiki = data[1]
df_wiki.to_excel('wiki.xlsx',index=False)

# %%
df1= pd.read_excel('wiki.xlsx')
df1
# Out:
#     Rank                     Country / Dependency         Total in km2 (mi2)  \
# 0    NaN                                    World  510,072,000 (196,940,000)
# 1      1                                   Russia     17,098,246 (6,601,670)
# 2    NaN                               Antarctica     14,200,000 (5,500,000)
# 3      2                           Canada[Note 1]      9,984,670 (3,855,100)
# 4    3/4                                    China      9,596,961 (3,705,407)
# ..   ...                                      ...                        ...
# 263  NaN  Ashmore and Cartier Islands (Australia)                    5 (1.9)
# 264  NaN               Spratly Islands (disputed)                    (< 1.9)
# 265  NaN            Coral Sea Islands (Australia)                    (< 1.2)
# 266  194                                   Monaco                2.02 (0.78)
# 267  195                             Vatican City                0.49 (0.19)
#
# ...
